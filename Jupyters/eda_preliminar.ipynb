# %% [markdown]
# # Analisis preliminar del conjunto de datos

# %%
# Importaciones
import pandas as pd

# %%
# Leer el archivo 
df_raw = pd.read_csv("../Data/bank-additional.csv")
df_raw.head()
# Out:
#    Unnamed: 0   age        job  marital    education  default  housing  loan  \
# 0           0   NaN  housemaid  MARRIED     basic.4y      0.0      0.0   0.0
# 1           1  57.0   services  MARRIED  high.school      NaN      0.0   0.0
# 2           2  37.0   services  MARRIED  high.school      0.0      1.0   0.0
# 3           3  40.0     admin.  MARRIED     basic.6y      0.0      0.0   0.0
# 4           4  56.0   services  MARRIED  high.school      0.0      0.0   1.0
#
#      contact  duration  ...  emp.var.rate  cons.price.idx  cons.conf.idx  \
# 0  telephone       261  ...           1.1          93,994          -36,4
# 1  telephone       149  ...           1.1          93,994          -36,4
# 2  telephone       226  ...           1.1          93,994          -36,4
# 3  telephone       151  ...           1.1          93,994          -36,4
# 4  telephone       307  ...           1.1          93,994          -36,4
#
# ...

# %%
df_raw.shape
# Out:
# (43000, 24)

# %%
print(f"El número de filas del conjunto de datos es: {df_raw.shape[0]}")
print(f"El número de columnas del conjunto de datos es: {df_raw.shape[1]}")
# Out:
# El número de filas del conjunto de datos es: 43000
# El número de columnas del conjunto de datos es: 24

# %%
df_raw.columns
# Out:
# Index(['Unnamed: 0', 'age', 'job', 'marital', 'education', 'default',
#        'housing', 'loan', 'contact', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx',
#        'cons.conf.idx', 'euribor3m', 'nr.employed', 'y', 'date', 'latitude',
#        'longitude', 'id_'],
#       dtype='object')

# %%
df_raw.sample()
# Out:
#        Unnamed: 0   age         job   marital          education  default  \
# 35416       35560  35.0  technician  DIVORCED  university.degree      0.0
#
#        housing  loan   contact  duration  ...  emp.var.rate  cons.price.idx  \
# 35416      0.0   0.0  cellular       169  ...          -1.8          92,893
#
#        cons.conf.idx euribor3m  nr.employed   y              date latitude  \
# 35416          -46,2       NaN       5099,1  no  6-noviembre-2018   40.562
#
#       longitude                                   id_
# 35416  -115.776  3047a700-9f05-4015-bf46-6a23f2dd5bbb
#
# [1 rows x 24 columns]

# %%
df_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43000 entries, 0 to 42999
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      43000 non-null  int64
#  1   age             37880 non-null  float64
#  2   job             42655 non-null  object
#  3   marital         42915 non-null  object
#  4   education       41193 non-null  object
#  5   default         34019 non-null  float64
#  6   housing         41974 non-null  float64
#  7   loan            41974 non-null  float64
#  8   contact         43000 non-null  object
#  9   duration        43000 non-null  int64
#  10  campaign        43000 non-null  int64
#  11  pdays           43000 non-null  int64
#  12  previous        43000 non-null  int64
#  13  poutcome        43000 non-null  object
#  14  emp.var.rate    43000 non-null  float64
#  15  cons.price.idx  42529 non-null  object
#  16  cons.conf.idx   43000 non-null  object
# ...

# %%
# Crear un dataframe con el que trabajar
df = df_raw.copy()

# %%
# Cambiar el nombre de las columnas 
df.columns = df.columns.str.replace(".","_").str.lower()
df.columns
# Out:
# Index(['unnamed: 0', 'age', 'job', 'marital', 'education', 'default',
#        'housing', 'loan', 'contact', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'emp_var_rate', 'cons_price_idx',
#        'cons_conf_idx', 'euribor3m', 'nr_employed', 'y', 'date', 'latitude',
#        'longitude', 'id_'],
#       dtype='object')

# %%
# Nos cargamos la columna unnamed ya que es el indice generado por pandas de manera automática
df.drop(columns="unnamed:_0",inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 2
#       1 # Nos cargamos la columna unnamed ya que es el indice generado por pandas de manera automática
# ----> 2 df.drop(columns="unnamed:_0",inplace=True)
#
# File ~/Desktop/EDA_Banco_Portugal/venv/lib/python3.13/site-packages/pandas/core/frame.py:5588, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5440 def drop(
#    5441     self,
#    5442     labels: IndexLabel | None = None,
#    (...)   5449     errors: IgnoreRaise = "raise",
#    5450 ) -> DataFrame | None:
#    5451     """
#    5452     Drop specified labels from rows or columns.
#    5453
#    (...)   5586             weight  1.0     0.8
#    5587     """
# -> 5588     return super().drop(
#    5589         labels=labels,
#    5590         axis=axis,
#    5591         index=index,
# ...

# %%
df.head()
# Out:
#     age        job  marital    education  default  housing  loan    contact  \
# 0   NaN  housemaid  MARRIED     basic.4y      0.0      0.0   0.0  telephone
# 1  57.0   services  MARRIED  high.school      NaN      0.0   0.0  telephone
# 2  37.0   services  MARRIED  high.school      0.0      1.0   0.0  telephone
# 3  40.0     admin.  MARRIED     basic.6y      0.0      0.0   0.0  telephone
# 4  56.0   services  MARRIED  high.school      0.0      0.0   1.0  telephone
#
#    duration  campaign  ...  emp_var_rate  cons_price_idx cons_conf_idx  \
# 0       261         1  ...           1.1          93,994         -36,4
# 1       149         1  ...           1.1          93,994         -36,4
# 2       226         1  ...           1.1          93,994         -36,4
# 3       151         1  ...           1.1          93,994         -36,4
# 4       307         1  ...           1.1          93,994         -36,4
#
#    euribor3m nr_employed   y                date latitude longitude  \
# ...

# %%
#Guardo porque termino sesión 
df.to_csv("../Data/data_transformacion_limpieza.csv", index=False)
